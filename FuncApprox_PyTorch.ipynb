# %% [markdown]
# Vamos tentar aprender a função
# $$
# u = \sin(x),\quad  x \in (0, 2\pi)
# $$
#
# usando rede neural feed-forward.
#
# ##### Gerar um dataset
#
# O traning set:
# $$
# S = {(x_i,u_i), i= 1, \cdots, n}\\
# x_i \approx U(0, 2\pi), \quad u_i \approx N(sin(x_i), \sigma(x_i))
# $$
#
# Com $U(a,b)$ sendo uma distribuição aleatória uniforme e $N(\mu,\sigma)$ é uma distribuição normal.

# %%
# !pip install torch
# !pip install numpy
# !pip install matplotlib
# Out:
# Requirement already satisfied: torch in ./.venv/lib64/python3.14/site-packages (2.10.0)
# Requirement already satisfied: filelock in ./.venv/lib64/python3.14/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib64/python3.14/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in ./.venv/lib64/python3.14/site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib64/python3.14/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib64/python3.14/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in ./.venv/lib64/python3.14/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./.venv/lib64/python3.14/site-packages (from torch) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in ./.venv/lib64/python3.14/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.venv/lib64/python3.14/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.venv/lib64/python3.14/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.venv/lib64/python3.14/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.venv/lib64/python3.14/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.venv/lib64/python3.14/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.venv/lib64/python3.14/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.venv/lib64/python3.14/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.venv/lib64/python3.14/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.venv/lib64/python3.14/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.venv/lib64/python3.14/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.venv/lib64/python3.14/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in ./.venv/lib64/python3.14/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.venv/lib64/python3.14/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.venv/lib64/python3.14/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.venv/lib64/python3.14/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in ./.venv/lib64/python3.14/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in ./.venv/lib64/python3.14/site-packages (from cuda-bindings==12.9.4->torch) (1.3.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib64/python3.14/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib64/python3.14/site-packages (from jinja2->torch) (3.0.3)
# Collecting numpy
#   Downloading numpy-2.4.2-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.2-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 6.7 MB/s  0:00:02m0:00:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.2
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp314-cp314-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib64/python3.14/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib64/python3.14/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib64/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 6.6 MB/s  0:00:01m0:00:0100:01
# Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (363 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp314-cp314-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 6.9 MB/s  0:00:00 eta 0:00:01
# Downloading kiwisolver-1.4.9-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.1 MB/s  0:00:00 eta 0:00:01
# Downloading pillow-12.1.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 6.8 MB/s  0:00:01 eta 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2

# %%
# Bibliotecas

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ##### Gerar um dataset
#
# O traning set:
# $$
# S = {(x_i,u_i), i= 1, \cdots, n}\\
# x_i \approx U(0, 2\pi), \quad u_i \approx N(sin(x_i), \sigma(x_i))
# $$
#
# Com $U(a,b)$ sendo uma distribuição aleatória uniforme e $N(\mu,\sigma)$ é uma distribuição normal.

# %%
# Gerar os dados sintéticos
def generate_data(num_points, noise_std=0.1):
    # Gerar valores x uniformemente distribuídos entre 0 e 2π
    x_values = np.sort(np.random.uniform(0, 2 * np.pi, num_points))
    y_values = np.sin(x_values) + np.random.normal(0, noise_std, num_points)
    return x_values, y_values

num_points = 1000

x_train, y_train = generate_data(num_points, noise_std=0.1)

# %% [markdown]
# ##### Definição do modelo
#
# Usamos uma **rede neural feedforward** (**MLP**) para aproximar a função
#
# $$
# u = \sin(x)
# $$
#
# Dada uma entrada $x \in D \subset \mathbb{R}^n$, uma rede neural feedforward a transforma em uma saída $u_{\theta}(x) \in \mathbb{R}^m$ por meio de camadas de unidades (neurônios). Essas camadas são compostas por:
#
# - transformações afim-lineares entre neurônios de camadas sucessivas, e
# - funções de ativação escalares não lineares dentro de cada neurônio.
#
# Isso resulta na seguinte representação:
#
# $$
# u_{\theta}(x) = C_K \circ A \circ C_{K-1} \circ \ldots \circ A \circ C_2 \circ A \circ C_1(x).
# $$
#
# Aqui, $\circ$ denota a **composição de funções** e $A$ é uma **função de ativação escalar (não linear)**.
#
# Para qualquer $1 \leq k \leq K$, definimos
#
# $$
# C_k z_k = W_k z_k + b_k, \quad \text{onde } W_k \in \mathbb{R}^{d_{k+1} \times d_k},\; z_k \in \mathbb{R}^{d_k},\; b_k \in \mathbb{R}^{d_{k+1}}.
# $$
#
# Também denotamos
#
# $$
# \theta = \{W_k, b_k\}, \qquad \theta_W = \{W_k\} \quad \forall\, 1 \leq k \leq K,
# $$
#
# como o conjunto completo de **parâmetros ajustáveis (pesos)** da rede.
